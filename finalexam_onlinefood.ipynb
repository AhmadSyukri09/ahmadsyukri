# %% [markdown]
# # Load Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
food = pd.read_csv("onlinefoods.csv")
food
# Out:
#      Age  Gender MaritalStatus Occupation   MonthlyIncome  \
# 0     20  Female        Single    Student       No Income
# 1     24  Female        Single    Student  Below Rs.10000
# 2     22    Male        Single    Student  Below Rs.10000
# 3     22  Female        Single    Student       No Income
# 4     22    Male        Single    Student  Below Rs.10000
# ..   ...     ...           ...        ...             ...
# 383   23  Female        Single    Student       No Income
# 384   23  Female        Single    Student       No Income
# 385   22  Female        Single    Student       No Income
# 386   23    Male        Single    Student  Below Rs.10000
# 387   23    Male        Single    Student       No Income
#
#     EducationalQualifications  Familysize  latitude  longitude  Pincode  \
# 0               Post Graduate           4   12.9766    77.5993   560001
# 1                    Graduate           3   12.9770    77.5773   560009
# ...

# %%
#variabel selection
df= food[['Age', 'Gender', 'Occupation', 'MonthlyIncome', 'EducationalQualifications','Feedback']]
df.head()
# Out:
#    Age  Gender Occupation   MonthlyIncome EducationalQualifications   Feedback
# 0   20  Female    Student       No Income             Post Graduate   Positive
# 1   24  Female    Student  Below Rs.10000                  Graduate   Positive
# 2   22    Male    Student  Below Rs.10000             Post Graduate  Negative
# 3   22  Female    Student       No Income                  Graduate   Positive
# 4   22    Male    Student  Below Rs.10000             Post Graduate   Positive

# %%
# Display basic information about the dataset
print(df.info())
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 388 entries, 0 to 387
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Age                        388 non-null    int64
#  1   Gender                     388 non-null    object
#  2   MaritalStatus              388 non-null    object
#  3   Occupation                 388 non-null    object
#  4   MonthlyIncome              388 non-null    object
#  5   EducationalQualifications  388 non-null    object
#  6   Familysize                 388 non-null    int64
#  7   latitude                   388 non-null    float64
#  8   longitude                  388 non-null    float64
#  9   Pincode                    388 non-null    int64
#  10  Output                     388 non-null    object
#  11  Feedback                   388 non-null    object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 36.5+ KB
# None
# ...

# %%
# Drop the 'Unnamed: 12' column as it is a duplicate
df = df.drop(columns=['Unnamed: 12'])

# %%
df
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 0     20  Female         Single    Student       No Income
# 1     24  Female         Single    Student  Below Rs.10000
# 2     22    Male         Single    Student  Below Rs.10000
# 3     22  Female         Single    Student       No Income
# 4     22    Male         Single    Student  Below Rs.10000
# ..   ...     ...            ...        ...             ...
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                Post Graduate            4   12.9766    77.5993    560001
# 1                     Graduate            3   12.9770    77.5773    560009
# ...

# %% [markdown]
# # Handle Missing Value

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder

# Handle missing values
df = df.fillna(df.mode().iloc[0])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 388 entries, 0 to 387
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Age                        388 non-null    int64
#  1   Gender                     388 non-null    object
#  2   MaritalStatus              388 non-null    object
#  3   Occupation                 388 non-null    object
#  4   MonthlyIncome              388 non-null    object
#  5   EducationalQualifications  388 non-null    object
#  6   Familysize                 388 non-null    int64
#  7   latitude                   388 non-null    float64
#  8   longitude                  388 non-null    float64
#  9   Pincode                    388 non-null    int64
#  10  Output                     388 non-null    object
#  11  Feedback                   388 non-null    object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 36.5+ KB

# %% [markdown]
# # Mengkodekan Variabel Kategori

# %%
# Encode categorical variables
categorical_cols = ['Gender', 'Occupation', 'EducationalQualifications']
label_encoders = {col: LabelEncoder() for col in categorical_cols}

def encode_MonthlyIncome(MonthlyIncome):
    if MonthlyIncome == 'No Income':
        return 0
    elif MonthlyIncome == 'Below Rs.10000':
        return 1
    elif MonthlyIncome == '10001 to 25000':
        return 2
    elif MonthlyIncome == '25001 to 50000':
        return 3
    elif MonthlyIncome == 'More than 50000':
        return 4
    else:
        return None

# Terapkan fungsi pada kolom 'Income'
df['MonthlyIncome'] = df['MonthlyIncome'].apply(encode_MonthlyIncome)

for col in categorical_cols:
    df[col] = label_encoders[col].fit_transform(df[col])

# Convert 'Output' to binary: Yes=1, No=0
df['Feedback'] = df['Feedback'].apply(lambda x: 1 if x == 'Positive' else 0)

# %%
df
# Out:
#      Age  Gender MaritalStatus  Occupation  MonthlyIncome  \
# 0     20       0        Single           3              0
# 1     24       0        Single           3              1
# 2     22       1        Single           3              1
# 3     22       0        Single           3              0
# 4     22       1        Single           3              1
# ..   ...     ...           ...         ...            ...
# 383   23       0        Single           3              0
# 384   23       0        Single           3              0
# 385   22       0        Single           3              0
# 386   23       1        Single           3              1
# 387   23       1        Single           3              0
#
#      EducationalQualifications  Familysize  latitude  longitude  Pincode  \
# 0                            2           4   12.9766    77.5993   560001
# 1                            0           3   12.9770    77.5773   560009
# ...

# %%
# Scale numerical features

# Split the dataset into training and testing sets
x = df[['Age', 'Gender', 'Occupation', 'MonthlyIncome', 'EducationalQualifications']]
y = LabelEncoder().fit_transform(df['Feedback'])
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# EDA Visualization
sns.countplot(x='Feedback', data=df)
plt.title('Feedback Distribution')
plt.show()

sns.boxplot(x='Feedback', y='Age', data=df)
plt.title('Age vs Feedback')
plt.show()

sns.countplot(x='MonthlyIncome', hue='Feedback', data=df)
plt.title('Monthly Income vs Output')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[94], line 10
#       7 plt.title('Age vs Feedback')
#       8 plt.show()
# ---> 10 sns.countplot(x='MonthlyIncome', hue='Feedback', data=df)
#      11 plt.title('Monthly Income vs Output')
#      12 plt.show()
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\seaborn\categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File c:\Users\DELL\anaconda3\Lib\site-packages\seaborn\categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# ...

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Model Training and Comparison
def evaluate_model(y_test, y_pred):
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')
    f1 = f1_score(y_test, y_pred, average='weighted')
    return accuracy, precision, recall, f1

# Logistic Regression
lr = LogisticRegression()
lr.fit(X_train, y_train)
y_pred_lr = lr.predict(X_test)

# Decision Tree
dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
y_pred_dt = dt.predict(X_test)

# SVM
svm = SVC()
svm.fit(X_train, y_train)
y_pred_svm = svm.predict(X_test)

# Evaluate models
metrics_lr = evaluate_model(y_test, y_pred_lr)
metrics_dt = evaluate_model(y_test, y_pred_dt)
metrics_svm = evaluate_model(y_test, y_pred_svm)

print("Logistic Regression - Accuracy: {:.2f}, Precision: {:.2f}, Recall: {:.2f}, F1-Score: {:.2f}".format(*metrics_lr))
print("Decision Tree - Accuracy: {:.2f}, Precision: {:.2f}, Recall: {:.2f}, F1-Score: {:.2f}".format(*metrics_dt))
print("SVM - Accuracy: {:.2f}, Precision: {:.2f}, Recall: {:.2f}, F1-Score: {:.2f}".format(*metrics_svm))
# Out:
# Logistic Regression - Accuracy: 0.86, Precision: 0.74, Recall: 0.86, F1-Score: 0.79
# Decision Tree - Accuracy: 0.81, Precision: 0.84, Recall: 0.81, F1-Score: 0.82
# SVM - Accuracy: 0.86, Precision: 0.74, Recall: 0.86, F1-Score: 0.79
# c:\Users\DELL\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\DELL\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Model Training and Comparison
def evaluate_model(y_test, y_pred):
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    return accuracy, precision, recall, f1

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

 # Logistic Regression
lr = LogisticRegression()
lr.fit(X_train, y_train)
y_pred_lr = lr.predict(X_test)

# %%
# Decision Tree
dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
y_pred_dt = dt.predict(X_test)

# SVM
svm = SVC()
svm.fit(X_train, y_train)
y_pred_svm = svm.predict(X_test)

# Evaluate models
metrics_lr = evaluate_model(y_test, y_pred_lr)
metrics_dt = evaluate_model(y_test, y_pred_dt)
metrics_svm = evaluate_model(y_test, y_pred_svm)

print("Logistic Regression - Accuracy: {:.2f}, Precision: {:.2f}, Recall: {:.2f}, F1-Score: {:.2f}".format(*metrics_lr))
print("Decision Tree - Accuracy: {:.2f}, Precision: {:.2f}, Recall: {:.2f}, F1-Score: {:.2f}".format(*metrics_dt))
print("SVM - Accuracy: {:.2f}, Precision: {:.2f}, Recall: {:.2f}, F1-Score: {:.2f}".format(*metrics_svm))
# Out:
# Logistic Regression - Accuracy: 0.86, Precision: 0.86, Recall: 1.00, F1-Score: 0.92
# Decision Tree - Accuracy: 0.82, Precision: 0.92, Recall: 0.87, F1-Score: 0.89
# SVM - Accuracy: 0.86, Precision: 0.86, Recall: 1.00, F1-Score: 0.92

# %%
print(X_train)
# Out:
#      Age  Gender  Occupation  MonthlyIncome  EducationalQualifications
# 63    23       1           3              0                          0
# 238   27       1           0              3                          0
# 132   23       1           3              0                          2
# 101   23       1           3              0                          2
# 351   25       1           2              4                          0
# ..   ...     ...         ...            ...                        ...
# 71    24       0           3              2                          2
# 106   26       1           0              4                          2
# 270   23       1           0              2                          0
# 348   20       1           3              0                          0
# 102   22       0           0              2                          0
#
# [310 rows x 5 columns]

# %%
import pandas as pd

data = {
    'Age': [20],
    'Gender': ['1'],
    'Occupation': ['2'],
    'MonthlyIncome' : ['0'],
    'EducationalQualifications': ['0']
}

df1 = pd.DataFrame(data)
print(df1)
# Out:
#    Age Gender Occupation MonthlyIncome EducationalQualifications
# 0   20      1          2             0                         0

# %%
pred1 = dt.predict(df1)
print(pred1)
# Out:
# [1]

# %%
pred2 = svm.predict(df1)
print(pred2)
# Out:
# [1]

# %%
pred3 = lr.predict(df1)
print(pred3)
# Out:
# [1]
